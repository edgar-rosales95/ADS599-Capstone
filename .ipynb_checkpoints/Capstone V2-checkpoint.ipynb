# %% [markdown]
# # Capstone (Rename Later)

# %% [markdown]
# ## Libraries Here

# %%
import sys
import kagglehub
import warnings
from pathlib import Path
import tifffile as tiff
import matplotlib.pyplot as plt
import random
import pandas as pd

# %% [markdown]
# # Load Data

# %%
# !{sys.executable} -m pip install kagglehub tifffile
# Out:
# Requirement already satisfied: kagglehub in ./anaconda3/lib/python3.10/site-packages (0.3.12)
# Requirement already satisfied: tifffile in ./anaconda3/lib/python3.10/site-packages (2025.5.10)
# Requirement already satisfied: packaging in ./anaconda3/lib/python3.10/site-packages (from kagglehub) (24.2)
# Requirement already satisfied: requests in ./anaconda3/lib/python3.10/site-packages (from kagglehub) (2.32.3)
# Requirement already satisfied: pyyaml in ./anaconda3/lib/python3.10/site-packages (from kagglehub) (6.0.2)
# Requirement already satisfied: tqdm in ./anaconda3/lib/python3.10/site-packages (from kagglehub) (4.67.1)
# Requirement already satisfied: numpy in ./anaconda3/lib/python3.10/site-packages (from tifffile) (1.26.4)
# Requirement already satisfied: idna<4,>=2.5 in ./anaconda3/lib/python3.10/site-packages (from requests->kagglehub) (3.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./anaconda3/lib/python3.10/site-packages (from requests->kagglehub) (3.3.2)
# Requirement already satisfied: certifi>=2017.4.17 in ./anaconda3/lib/python3.10/site-packages (from requests->kagglehub) (2025.4.26)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./anaconda3/lib/python3.10/site-packages (from requests->kagglehub) (2.3.0)

# %%
warnings.filterwarnings("ignore", category=UserWarning, module='keras.src.trainers.data_adapters.py_dataset_adapter')

# Download dataset locally
path = kagglehub.dataset_download("fpeccia/weed-detection-in-soybean-crops")
print("Path:", path)
# Out:
# Path: /Users/bobbymarriott/.cache/kagglehub/datasets/fpeccia/weed-detection-in-soybean-crops/versions/1

# %% [markdown]
# # Data Preparation and Exploratory Data Analysis

# %%
root = Path("/Users/bobbymarriott/.cache/kagglehub/datasets/fpeccia/weed-detection-in-soybean-crops/versions/1")
base = root / "dataset" / "dataset"

# Univariate EDA: count images per class
classes = sorted(p.name for p in base.iterdir() if p.is_dir())
counts = {cls: len(list((base/cls).iterdir())) for cls in classes}
df_counts = pd.DataFrame.from_dict(counts, orient='index', columns=['image_count'])
df_counts.index.name = 'class'
print(df_counts)

# Resolution profiling: sample up to 50 images per class and record their sizes
records = []
for cls in classes:
    files = list((base/cls).iterdir())
    sample = random.sample(files, min(50, len(files)))
    for f in sample:
        img = tiff.imread(f)
        records.append({'class': cls, 'height': img.shape[0], 'width': img.shape[1]})

df_shapes = pd.DataFrame(records)
print(df_shapes.groupby('class')[['height','width']].agg(['min','mean','max']))

# Scatter-plot of sampled dimensions
plt.figure(figsize=(8,6))
for cls in classes:
    sub = df_shapes[df_shapes['class']==cls]
    plt.scatter(sub['width'], sub['height'], alpha=0.6, label=cls)
plt.xlabel("Width (px)"); plt.ylabel("Height (px)")
plt.title("Image Dimensions by Class"); plt.legend(); plt.show()
# Out:
#            image_count
# class
# broadleaf         1191
# grass             3520
# soil              3249
# soybean           7376
#           height              width
#              min    mean  max   min    mean  max
# class
# broadleaf    182  244.32  295   142  244.26  316
# grass        189  244.98  293   202  245.82  304
# soil         171  245.58  330   186  245.24  306
# soybean      166  239.38  311   196  248.46  316

# %% [markdown]
# This dataset is imbalanced with soybean having 7,376 samples, while broadleaf, grass, and soil have 1,191, 3,520, and 3,249 images respectively. This will need to be corrected with class weighting or another method.
#
# Additionally, we have sampled the image dimensions by class and the dimensions range from 158 x 184 px to 404 x 324 px. This may need to be resized to a uniform input size such as 224 x 224 px, for example.
